# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import gridspec as gs
width = matplotlib.rcParams["figure.figsize"][0]
height = matplotlib.rcParams["figure.figsize"][1]
import PIL
import archivedb
import datetime
import time

# %%
import importlib

# %%
importlib.reload(archivedb)
# Out:
# <module 'archivedb' from '/home/boz/progs/py/ArchiveDB/archivedb/__init__.py'>

# %%
archivedb
# Out:
# <module 'archivedb' from '/home/boz/progs/py/ArchiveDB/archivedb/__init__.py'>

# %%
archivedb.get_version_info("ArchiveDB/raw/W7X/CBG_ECRH/TotalPower_PARLOG", None)#, protocol="json")
# Out:
# {'versionInfo': [{'analysis_environment': 'pc7ecrhsrne',
#    'code_release': '1.0',
#    'creation_tag': 1506430456786000000,
#    'number': 1,
#    'producer': 'ecrhwincc',
#    'reason': 'scaling coefficients from file 20170925_Gyrotorn-calibration_losscorr.txt, arbitrary scaling for B1 200kWm^-2V^-1'},
#   {'analysis_environment': 'pc7ecrhsrne',
#    'code_release': '1.1',
#    'creation_tag': 1507891759052000000,
#    'number': 2,
#    'producer': 'ecrhwincc',
#    'reason': 'scaling coefficients from file 20170925_Gyrotorn-calibration_losscorr.txt, arbitrary scaling for B1 200kWm^-2V^-1, read only gyrotrons found in tags from W7-X logbook'},
#   {'analysis_environment': 'pc7ecrhsrne',
#    'code_release': 'No code release specified',
#    'creation_tag': 1560495052556000000,
#    'number': 3,
#    'producer': 'ecrhwincc',
#    'reason': 'Automatic version increase by post processing routines / No specific reason given by the user'}]}

# %%
archivedb.get_version_info("ArchiveDB/raw/W7X/CBG_ECRH/TotalPower_DATASTREAM", None)#, protocol="json")
# Out:
# {'versionInfo': [{'analysis_environment': 'pc7ecrhsrne',
#    'code_release': '1.0',
#    'creation_tag': 1506430456786000000,
#    'number': 1,
#    'producer': 'ecrhwincc',
#    'reason': 'scaling coefficients from file 20170925_Gyrotorn-calibration_losscorr.txt, arbitrary scaling for B1 200kWm^-2V^-1'},
#   {'analysis_environment': 'pc7ecrhsrne',
#    'code_release': '1.1',
#    'creation_tag': 1507891759052000000,
#    'number': 2,
#    'producer': 'ecrhwincc',
#    'reason': 'scaling coefficients from file 20170925_Gyrotorn-calibration_losscorr.txt, arbitrary scaling for B1 200kWm^-2V^-1, read only gyrotrons found in tags from W7-X logbook'},
#   {'analysis_environment': 'pc7ecrhsrne',
#    'code_release': 'No code release specified',
#    'creation_tag': 1560495052556000000,
#    'number': 3,
#    'producer': 'ecrhwincc',
#    'reason': 'Automatic version increase by post processing routines / No specific reason given by the user'}]}

# %%
archivedb.get_last_version_for_program('ArchiveDB/raw/W7X/CoDaStationDesc.10082/DataModuleDesc.10084_DATASTREAM/48/AAQ11_ActVal_I', "20171010.018") is None
# Out:
# True

# %%
archivedb.get_last_version_for_program('ArchiveDB/raw/W7X/CoDaStationDesc.10082/DataModuleDesc.10084_DATASTREAM/48/AAQ11_ActVal_I', "20171010.018") is None
# Out:
# True

# %%
s = "Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0"
p = s.rfind("/", 0, s.rfind("/"))
s[:p],s[p:]
# Out:
# ('Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM', '/0/channel_0')

# %%
archivedb.get_program_list_for_day("2018-10-04", protocol="cbor")
# Out:
# [{'description': 'trigger test\npellet test\nvalve BG0* test\n\n',
#   'from': 1538637583056968441,
#   'from_str': '1538637583056968441',
#   'id': '20181004.001',
#   'name': '#87137 test_trigger_valve_pellet',
#   'scenarios': [{'from': 1538637583056968441,
#     'id': 1,
#     'name': 'W7-X_Preparation',
#     'upto': 1538637639056968440},
#    {'from': 1538637639056968441,
#     'id': 2,
#     'name': 'W7-X_Plasma',
#     'upto': 1538637651556968440},
#    {'from': 1538637651556968441,
#     'id': 3,
#     'name': 'W7-X_post_processing',
#     'upto': 1538637656556968440}],
#   'sessionInfo': '',
#   'trigger': {'0': [1538637584056968441],
#    '1': [1538637644056968441],
#    '2': [],
#    '3': [],
#    '4': [1538637646056968441],
#    '5': [1538637651456968441],
#    '6': [1538637656456968441]},
#   'trigger_str': {'0': ['1538637584056968441'],
#    '1': ['1538637644056968441'],
#    '2': [],
#    '3': [],
#    '4': ['1538637646056968441'],
#    '5': ['1538637651456968441'],
# ...

# %%
t11,s11 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1/1/ne_map", "20171010.018",)
t2,s2 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V2/1/ne_map", "20171010.018",)
tl,sl = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/1/ne_map", "20171010.018", useLastVersion=True)

# %%
t1,s1 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1/1/ne_map", "20171010.018",
                                         useCache=0, protocol="cbor")
t2,s2 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V2/1/ne_map", "20171010.018",
                                         useCache=0,protocol="cbor")
tl,sl = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/1/ne_map", "20171010.018", 
                                         useLastVersion=True,protocol="cbor", useCache=0)

# %%
# %time t11,s11 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1/1/ne_map", "20171010.018",)
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 8.51 ms

# %%
# %time t11,s11 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1/1/ne_map", "20171010.018",)
# Out:
# CPU times: user 4 ms, sys: 8 ms, total: 12 ms
# Wall time: 164 ms

# %%
# %time t1,s1 = archivedb.get_signal_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1/1/ne_map", "20171010.018",useCache=0, protocol="cbor")
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 28.2 ms

# %%
plt.close("all")
plt.plot(t1,s1)
plt.plot(t11,s11)
# Out:
# <img src="data:image/png;base64,..." width="506">

# %%
t1,s1 = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1",
                                             "20171018.025", [0,1], useCache=0)
t2,s2 = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V2", "20171018.025", [0,1],
                                            useCache=0)
tl,sl = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM", "20171018.025", [0,1], 
                                             useLastVersion=True, useCache=0)

# %%
t1,s1 = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1",
                                             "20171018.025", [0,1], useCache=0, protocol="cbor")
t2,s2 = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V2", "20171018.025", [0,1],
                                            useCache=0, protocol="cbor")
tl,sl = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM", "20171018.025", [0,1], 
                                             useLastVersion=True, useCache=0, protocol="cbor")

# %%
s1.shape, t1.shape
# Out:
# ((2, 250), (250,))

# %%
t1,s1 = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB_Central/volume_2_DATASTREAM/V1",
                                             "20171018.025", [0,1], useCache=0, correctTime=False)
np.savez("tests/qtb_volume_2_box_20171018.025.npz", t=t1, s=s1)

# %%
plt.close("all")
plt.plot(t1, (s2[0,:] - s1[0,:]))
plt.plot(t1, (sl[0,:] - s2[0,:]))
# Out:
# <img src="data:image/png;base64,..." width="506.4">

# %%
s.rfind?

# %%
intervals = archivedb.get_time_intervals("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0", 1457431564197103981, "2016-03-08 10:10:00", maxIntervals=10)

# %%
intervals.shape
# Out:
# (10, 2)

# %%
intervals = archivedb.get_time_intervals("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0", 
                                         1457431564197103981, "2016-03-08 10:10:00", maxIntervals=10, protocol="cbor")
intervals
# Out:
# array([[1457431565097103981, 1457431565097105980],
#        [1457431564997103981, 1457431564997105980],
#        [1457431564897103981, 1457431564897105980],
#        [1457431564797103981, 1457431564797105980],
#        [1457431564697103981, 1457431564697105980],
#        [1457431564597103981, 1457431564597105980],
#        [1457431564497103981, 1457431564497105980],
#        [1457431564397103981, 1457431564397105980],
#        [1457431564297103981, 1457431564297105980],
#        [1457431564197103981, 1457431564197105980]])

# %%
t, s= archivedb.get_signal("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0", 1457431565097103981, 1457431565097105980)

# %%
t, s= archivedb.get_signal("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0", 
                           1457431565097103981, 1457431565097105980, protocol="cbor")

# %%
print(t.shape, s.shape)
# Out:
# (2000,) (2000,)

# %%
t, s= archivedb.get_signal_box("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM",
                               1457431565097103981, 1457431565097105980, [0,1], useCache=0)

# %%
t, s= archivedb.get_signal_box("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM",
                               1457431565097103981, 1457431565097105980, [0,1], useCache=0, protocol="cbor")

# %%
print(t.shape, s.shape)
# Out:
# (2000,) (2, 2000)

# %%
t, s= archivedb.get_signal_box_multiinterval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM", intervals, [0,1])

# %%
t, s= archivedb.get_signal_box_multiinterval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM", 
                                             intervals, [0,1], protocol="cbor")

# %%
print(t.shape, s.shape)
# Out:
# (20000,) (2, 20000)

# %%
t, s = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM", "20160310.001", [1,2])

# %%
t, s = archivedb.get_signal_box_for_program("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM", "20160310.001", [1,2],
                                           protocol="cbor")

# %%
print(t.shape, s.shape)
# Out:
# (110000,) (2, 110000)

# %%
t, s= archivedb.get_signal_multiinterval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0", intervals)

# %%
t, s= archivedb.get_signal_multiinterval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0",
                                         intervals, protocol="cbor", useCache=0)

# %%
print(t.shape, s.shape)
# Out:
# (20000,) (20000,)

# %%
# %time t,s = archivedb.get_signal_for_program("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0", "20160310.007", useCache=0)
# Out:
# CPU times: user 1.02 s, sys: 104 ms, total: 1.12 s
# Wall time: 2.31 s

# %%
# %time t,s = archivedb.get_signal_for_program("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0","20160310.007", useCache=0, protocol="cbor")
# Out:
# CPU times: user 964 ms, sys: 56 ms, total: 1.02 s
# Wall time: 1.94 s

# %%
print(t.shape, s.shape)
# Out:
# (194000,) (194000,)

# %%
plt.close("all")
plt.plot(s.T)
# Out:
# <img src="data:image/png;base64,..." width="506.4">

# %%
t, d = archivedb.get_image_png('Test/raw/Data4SoftwareTest/Hdf5.video.Test2/pixelfly_DATASTREAM',1421229109876999999,1421229109967000000)

# %%
print(d.shape)
# Out:
# (1392, 1024)

# %%
# %time t, d =  archivedb.get_image('ArchiveDB/raw/W7X/QSR_Limiter_NIR/AEF10_A_Port_DATASTREAM',"2016-03-10 15:00:29.9", "2016-03-10 15:00:30")
# Out:
# CPU times: user 1.49 s, sys: 56 ms, total: 1.54 s
# Wall time: 1.83 s

# %%
print(d.shape)
# Out:
# (5, 288, 720)

# %%
# %time t, d =  archivedb.get_image('ArchiveDB/raw/W7X/QSR_Limiter_NIR/AEF10_A_Port_DATASTREAM',"2016-03-10 15:00:29.9", "2016-03-10 15:00:30", protocol="cbor")
# Out:
# CPU times: user 1.46 s, sys: 0 ns, total: 1.46 s
# Wall time: 1.8 s

# %%
d.shape, t.shape
# Out:
# ((5, 288, 720), (5,))

# %%
t, d =  archivedb.get_image_png_multiple('ArchiveDB/raw/W7X/QSR_Limiter_NIR/AEF10_A_Port_DATASTREAM',"2016-03-10 15:00:29.9", "2016-03-10 15:00:30",
                                        useCache = False)

# %%
print(d.shape, t.shape)
# Out:
# (5, 288, 720) (5,)

# %%
archivedb.get_parameters_box_for_program("ArchiveDB/raw/W7X/CoDaStationDesc.14823/DataModuleDesc.14833_PARLOG", 
                                         "20171018.020")
# Out:
# {'dimensions': [1506513368198000001, 1530191089269999999],
#  'values': [{'parms': {'__source_class_name__': 'de.mpg.ipp.codac.business.schema.ParamSetFlexibleDataModule',
#     'chanDescs': {'[0]': {'__source_class_name__': 'de.mpg.ipp.codac.business.schema.ChannelDesc',
#       'active': 1,
#       'name': 'image',
#       'physicalQuantity': {'__source_class_name__': 'de.mpg.ipp.codac.business.schema.InputRange',
#        'from': -10.0,
#        'type': 'V',
#        'upto': 10.0}}},
#     'className': 'ParamSetFlexibleDataModule',
#     'dataBoxElementLength': 1,
#     'dataBoxSize': 1,
#     'details': {'[0]': {'__source_class_name__': 'de.mpg.ipp.codac.business.schema.segment.ParameterString',
#       'actValue': 'image',
#       'id': 0,
#       'name': 'signalProviderSpecifier'},
#      '[1]': {'__source_class_name__': 'de.mpg.ipp.codac.business.schema.segment.ParameterString',
#       'actValue': 'control',
#       'id': 0,
#       'name': 'controllableSpecifier'},
# ...

# %%
plt.close("all")
plt.imshow(d[2])
# Out:
# <img src="data:image/png;base64,..." width="506.4">

# %%
archivedb.get_latest_time_interval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0")
# Out:
# array([1457642948799554801, 1457642948799556800])

# %%
archivedb.get_latest_time_interval("Test/raw/W7X/QTB/ADQ14DC_SPD-04381_DATASTREAM/0/channel_0", protocol="cbor")
# Out:
# array([1457642948799554801, 1457642948799556800])

# %%
archivedb.print_info()
# Out:
#     A set of functions to work with W7-X Archivedb via web-api.
#
#     Simple function to read from and to write to the database are available.
#     This includes reading/writing arrays, images. Also reading of
#     performed programs is available.
#
# Version: 2019.12.3_0
# Author: boz dsk
# Cache path: /home/boz/.archivedb/cache/
# DB URL: http://archive-webapi.ipp-hgw.mpg.de/
# MDSPlus: http://10.44.4.11/operator/find_pulse/

# %%
archivedb.return_library_version()
# Out:
# '2019.12.3_0'

# %%
archivedb.utils.to_timestamp("2016-03-10 12:00:00"), archivedb.utils.to_timestamp("2016-03-10 12:00:00.1213")
# Out:
# (1457611200000000000, 1457611200121300000)

# %%
len(archivedb.get_program_list_for_day("2016-03-10"))
# Out:
# 40

# %%
archivedb.get_program_list_for_day("2016-03-10")[0]
# Out:
# {'description': 'combined trigger dry run for diagnostics and GasInlet test puff\nH2 Puff_20ms at BG35\nH2 Puff 20ms at BG23\nECRH off',
#  'from': 1457599965437656661,
#  'from_str': '1457599965437656661',
#  'id': '20160310.001',
#  'name': '#24988 W7-X_combined_StandardTriggerTest_and_GasInletTestPulseH2_BG35&23',
#  'scenarios': [{'from': 1457599965437656661,
#    'id': 1,
#    'name': 'W7-X_Preparation',
#    'upto': 1457600021437656660},
#   {'from': 1457600021437656661,
#    'id': 2,
#    'name': 'W7-X_Trigger and GasInlet Test',
#    'upto': 1457600028437656660},
#   {'from': 1457600028437656661,
#    'id': 3,
#    'name': 'W7-X_post_processing',
#    'upto': 1457600032437656660}],
#  'sessionInfo': '',
#  'trigger': {'0': [1457599966437656661],
#   '1': [1457600026437656661],
#   '2': [1457600021437656661],
#   '3': [1457600025937656661],
#   '4': [1457600026387656661],
#   '5': [1457600026432656661],
#   '6': [1457600031437656661]},
# ...

# %%
archivedb.get_program_list_for_day("2016-03-10")[0]
# Out:
# {'description': 'combined trigger dry run for diagnostics and GasInlet test puff\nH2 Puff_20ms at BG35\nH2 Puff 20ms at BG23\nECRH off',
#  'from': 1457599965437656661,
#  'from_str': '1457599965437656661',
#  'id': '20160310.001',
#  'name': '#24988 W7-X_combined_StandardTriggerTest_and_GasInletTestPulseH2_BG35&23',
#  'scenarios': [{'from': 1457599965437656661,
#    'id': 1,
#    'name': 'W7-X_Preparation',
#    'upto': 1457600021437656660},
#   {'from': 1457600021437656661,
#    'id': 2,
#    'name': 'W7-X_Trigger and GasInlet Test',
#    'upto': 1457600028437656660},
#   {'from': 1457600028437656661,
#    'id': 3,
#    'name': 'W7-X_post_processing',
#    'upto': 1457600032437656660}],
#  'sessionInfo': '',
#  'trigger': {'0': [1457599966437656661],
#   '1': [1457600026437656661],
#   '2': [1457600021437656661],
#   '3': [1457600025937656661],
#   '4': [1457600026387656661],
#   '5': [1457600026432656661],
#   '6': [1457600031437656661]},
# ...

# %%
archivedb.get_program_id(1457599965437656661, protocol="cbor")
# Out:
# '20160310.001'

# %%
archivedb.get_program_t0('20160310.001')
# Out:
# 1457599966437656661

# %%
archivedb.get_program_t0('20160310.001', protocol="cbor")
# Out:
# 1457599966437656661

# %%
archivedb.get_program_from_to('20160310.002', protocol="cbor")
# Out:
# (1457600637990656661, 1457600704711656660)

# %%
archivedb.get_mdsplus_shot(1457599966437656661)
# Out:
# 160310001

# %%
archivedb.utils.to_stringdate(1457599966437656661)
# Out:
# '2016-03-10 08:52:46.437657'

# %%
print(len(archivedb.get_program_list("2016-03-10 00:00:01", "2016-03-10 23:59:59")))
# Out:
# 40

# %%
d = { 'chanDescs': {
                                        '[0]':{
                                            'name' : 'Alpha', 
                                            'active' : 1, 
                                            'physicalQuantity' : { 'type' : 'X'}
                                        },
                                        '[1]' : 
                                        {
                                            'name' : 'Zeta', 
                                            'active' : 1, 
                                            'physicalQuantity' : { 'type' : 'X'}
                                        }
                                                 },
                       'powerLevel' : 100 } 
name = 'Test/raw/W7XAnalysis/webapi-tests/pythonTest178_PARLOG/'
t = int(round(time.time() * 1000)) * 1000000
archivedb.write_parameters(name, d, [t, -1])
# Out:
# True

# %%
d = { 'chanDescs': {
                                        '[0]':{
                                            'name' : 'Alpha', 
                                            'active' : 1, 
                                            'physicalQuantity' : { 'type' : 'X'}
                                        },
                                        '[1]' : 
                                        {
                                            'name' : 'Zeta', 
                                            'active' : 1, 
                                            'physicalQuantity' : { 'type' : 'X'}
                                        }
                                                 },
                       'powerLevel' : 100 } 
name = 'Test/raw/W7XAnalysis/webapi-tests/pythonTest178_PARLOG/'
t = int(round(time.time() * 1000)) * 1000000
archivedb.write_parameters(name, d, [t, -1], protocol="cbor")
# Out:
# True

# %%
archivedb.get_parameters_box(name, t, -1)
# Out:
# {'dimensions': [1575478028264000000, -1],
#  'label': 'parms',
#  'values': [{'chanDescs': {'[0]': {'active': 1,
#      'name': 'Alpha',
#      'physicalQuantity': {'type': 'X'}},
#     '[1]': {'active': 1, 'name': 'Zeta', 'physicalQuantity': {'type': 'X'}}},
#    'powerLevel': 100}]}

# %%
my_timestamp = int(round(time.time() * 1000)) * 1000000
timestamps=[my_timestamp, my_timestamp+1, my_timestamp+2,my_timestamp+3,my_timestamp+4]
archivedb.write_signal('Test/raw/W7XAnalysis/webapi-tests/pythonTest1_DATASTREAM/',
                    timestamps, [[11,2,3,4,15],[22,24,23,44,215]])
# Out:
# True

# %%
my_timestamp = int(round(time.time() * 1000)) * 1000000
timestamps=[my_timestamp, my_timestamp+1, my_timestamp+2,my_timestamp+3,my_timestamp+4]
archivedb.write_signal('Test/raw/W7XAnalysis/webapi-tests/pythonTest1_DATASTREAM/',
                    timestamps, [[11,2,3,4,15],[22,24,23,44,215]], protocol="cbor")
# Out:
# True

# %%
im = PIL.Image.open("/home/boz/docs/students/practicum/Dinesh_Kannan/w7x.jpg")
width, height = im.size
image = np.array(im.getdata()).reshape(height, width, 3).sum(axis=-1)
d =  {"projectName":"test data", "cameraType":"test data",
            "height" : 287,
            "width" : 380,
            "bitDepth" : 10,
            "dataBoxSize" : 1,
            "datatype" : "short",
            "unsigned" : 1}
        
archivedb.write_image_to_database("Test/raw/W7XAnalysis/HDF5_import_test/",
                                  archivedb.utils.to_timestamp("2019-01-05 12:30:00"), image, d)
# Out:
# True
